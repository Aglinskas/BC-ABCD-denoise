# %%
# !date
# Out:
# Tue Nov 11 11:02:21 AM EST 2025

# %%
pwd
# Out:
# '/projects/sccn/andromeda1/aglinska/BC-ABCD-denoise/Code'

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# %%
contrast_ABCD_place
# Out:
# (2, 33, 3)

# %%
contrast_forrest_place_v2 = np.load('../Data/betas_forrest_place_DeepCor-forrest-v4-beta-1e-5.npy')
contrast_forrest_face_v2 = np.load('../Data/betas_forrest_face_DeepCor-forrest-v4-beta-1e-5.npy')

contrast_ABCD_place_v2 = np.load('../Data/contrast_place_DeepCor-ABCD-nopreclean-beta-1e-5.npy')
contrast_ABCD_face_v2 = np.load('../Data/contrast_face_DeepCor-ABCD-nopreclean-beta-1e-5.npy')

contrast_things_place_v2 = np.load('../Data/contrast_place_DeepCor-things-nopreclean-beta-1e-5.npy')
contrast_things_face_v2 = np.load('../Data/contrast_face_DeepCor-things-nopreclean-beta-1e-5.npy')
